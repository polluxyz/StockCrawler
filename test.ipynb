# %%
import json
import requests
from datetime import date

# %%
url = "https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY"

res = requests.get(url, params={
    "response": "json",
    "date": "20240701",
    "stockNo": "1256"
})
res

# # 我們要的每日成交資訊在 data 這個欄位
# daily_price_list = res_json.get("data", [])

# # 該欄位是 List 所以用 for 迴圈印出
# for daily_price in daily_price_list:
#     print(daily_price)
# Out:
# <Response [200]>

# %%
# 把 JSON 轉成 Python 可存取之型態
res_json = res.json()
print(res_json)
# Out:
# {'stat': '查詢日期大於今日，請重新查詢!', 'total': 0}

# %%
today = date.today()
print(today.month)
# Out:
# 5

# %%
for n in range(3):
  print(n)
# Out:
# 0
# 1
# 2

# %%
with open("./stock_data/1213 大飲/date_info/2019_05.json","r",encoding="utf-8") as f:
  nothing = json.load(f)
print(nothing["total"])
# Out:
# 0

# %%
import os
PATH = "./stock_data/date_info/stocks/1101 台泥"
al = list(os.walk(PATH))[0][2][-1]
spl = al.split(".")[0].split("_")
print(spl)
# Out:
# ['2024', '05']

# %%
import os
import json
import time
import random
import requests
from pathlib import Path
from datetime import date

req = requests.Session()
url = "https://www.tpex.org.tw/web/stock/aftertrading/daily_trading_info/st43_result.php"

headers = req.headers

headers["User-Agent"] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36(KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36"

res = req.get(url,params={
                    "l": "zh-tw",
                    "d": "113/08",
                    "stkno": "6441"
                  })

print(res.json())
# Out:
# {'stkNo': '6441', 'stkName': '廣錠            ', 'showListPriceNote': False, 'showListPriceLink': False, 'reportDate': '113/08', 'iTotalRecords': 9, 'aaData': [['113/08/01', '134', '5,376', '40.05', '41.15', '40.00', '40.45', '0.65', '74'], ['113/08/02', '55', '2,185', '39.25', '40.30', '39.25', '39.40', '-1.05', '89'], ['113/08/05', '416', '14,876', '38.80', '38.80', '35.50', '35.50', '-3.90', '347'], ['113/08/06', '433', '14,364', '35.55', '36.65', '31.95', '33.80', '-1.70', '330'], ['113/08/07', '153', '5,522', '33.75', '36.90', '33.75', '36.90', '3.10', '152'], ['113/08/08', '75', '2,717', '36.35', '36.45', '35.65', '36.20', '-0.70', '177'], ['113/08/09', '94', '3,463', '36.20', '37.10', '36.15', '36.15', '-0.05', '261'], ['113/08/12', '82', '3,042', '36.25', '37.15', '36.20', '37.05', '0.90', '93'], ['113/08/13', '44', '1,606', '36.65', '37.00', '36.65', '36.85', '-0.20', '112']]}

# %%
from datetime import date

today = date.today()
year = today.year-1911
month = today.month
day = today.day
season = {
    1:4, 2:4, 3:4, 4:1, 5:1, 6:1, 7:2, 8:2, 9:2, 10:3, 11:3, 12:3
  }


type(month)
# Out:
# int
